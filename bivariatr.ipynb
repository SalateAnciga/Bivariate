# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
# ...

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        print(columnName)
        if(dataset[columnName].dtype=='O'):
            print("qual")
            qual.append(columnName)
        else:
            print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quanqual(dataset)
# Out:
# sl_no
# quan
# ssc_p
# quan
# hsc_p
# quan
# degree_p
# quan
# etest_p
# quan
# mba_p
# quan
# salary
# quan
# gender
# qual
# ssc_b
# qual
# hsc_b
# qual
# hsc_s
# qual
# degree_t
# qual
# workex
# qual
# specialisation
# qual
# status
# qual
# (['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary'],
#  ['gender',
#   'ssc_b',
#   'hsc_b',
#   'hsc_s',
#   'degree_t',
#   'workex',
#   'specialisation',
#   'status'])

# %%
quan,qual=quanqual(dataset)
# Out:
# sl_no
# quan
# ssc_p
# quan
# hsc_p
# quan
# degree_p
# quan
# etest_p
# quan
# mba_p
# quan
# salary
# quan
# gender
# qual
# ssc_b
# qual
# hsc_b
# qual
# hsc_s
# qual
# degree_t
# qual
# workex
# qual
# specialisation
# qual
# status
# qual

# %%
dataset.columns
# Out:
# Index(['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary',
#        'gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex',
#        'specialisation', 'status'],
#       dtype='object')

# %%
dataset[quan]
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0
# ..     ...    ...    ...       ...      ...    ...       ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0
#
# [148 rows x 7 columns]

# %%
dataset[quan].cov()
# Out:
#                   sl_no         ssc_p         hsc_p      degree_p  \
# sl_no       3682.366060    -49.439070   -123.657429    -40.443267
# ssc_p        -49.439070     75.958986     23.857269     21.624366
# hsc_p       -123.657429     23.857269     87.035238     13.457449
# degree_p     -40.443267     21.624366     13.457449     42.485464
# etest_p       34.547787     38.038056     36.462073     19.480243
# mba_p        -25.864836     22.082018     18.115677     18.951539
# salary    361617.668689  28777.386468  66977.716032 -11739.948520
#
#                 etest_p         mba_p        salary
# sl_no         34.547787    -25.864836  3.616177e+05
# ssc_p         38.038056     22.082018  2.877739e+04
# hsc_p         36.462073     18.115677  6.697772e+04
# degree_p      19.480243     18.951539 -1.173995e+04
# etest_p      188.494582     22.956336  2.287876e+05
# mba_p         22.956336     34.628316  9.624979e+04
# salary    228787.619507  96249.789024  8.734295e+09

# %%
# covariance of degree & enterance test is 19.480243.positive covariance
# covarianc of enterance test & mba  is  22.956336.positive covariance

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432  0.063764
# ssc_p    -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560  0.035330
# hsc_p    -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983  0.076819
# degree_p -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093 -0.019272
# etest_p   0.041467  0.317892  0.284672  0.217683  1.000000  0.284143  0.178307
# mba_p    -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000  0.175013
# salary    0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013  1.000000

# %%
#Correlation of salary & mba_p is 0.175013.	positive correlation
#if mba pass mark is high then salary is high but only 17% is increased

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           148 non-null    float64
#  1   ssc_p           148 non-null    float64
#  2   hsc_p           148 non-null    float64
#  3   degree_p        148 non-null    float64
#  4   etest_p         148 non-null    float64
#  5   mba_p           148 non-null    float64
#  6   salary          148 non-null    float64
#  7   gender          148 non-null    object
#  8   ssc_b           148 non-null    object
#  9   hsc_b           148 non-null    object
#  10  hsc_s           148 non-null    object
#  11  degree_t        148 non-null    object
#  12  workex          148 non-null    object
#  13  specialisation  148 non-null    object
#  14  status          148 non-null    object
# dtypes: float64(7), object(8)
# memory usage: 17.5+ KB

# %%
#convert categorial data into numercial data

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
for col in ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']:
    dataset[col] = label_encoder.fit_transform(dataset[col])

# %%
dataset[col]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 143    0
# 144    0
# 145    0
# 146    0
# 147    0
# Name: status, Length: 148, dtype: int32

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  gender  ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0       1      1
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0       1      0
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0       1      0
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0       1      0
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0       1      0
# ..     ...    ...    ...       ...      ...    ...       ...     ...    ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0       1      0
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0       1      1
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0       1      1
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0       1      1
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0       0      1
#
# ...

# %%
dataset.cov()
# Out:
#                         sl_no         ssc_p         hsc_p      degree_p  \
# sl_no             3682.366060    -49.439070   -123.657429    -40.443267
# ssc_p              -49.439070     75.958986     23.857269     21.624366
# hsc_p             -123.657429     23.857269     87.035238     13.457449
# degree_p           -40.443267     21.624366     13.457449     42.485464
# etest_p             34.547787     38.038056     36.462073     19.480243
# mba_p              -25.864836     22.082018     18.115677     18.951539
# salary          361617.668689  28777.386468  66977.716032 -11739.948520
# gender               2.252804     -0.718766     -0.103778     -0.606150
# ssc_b                0.595330      0.871333     -0.619924      0.323688
# hsc_b                1.231752      0.602957     -0.241812      0.238033
# hsc_s                0.611785      1.339424     -1.304446      0.581491
# degree_t             2.568579      1.963202     -0.759797      0.464510
# ...

# %%
dataset.corr()
# Out:
#                    sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p  \
# sl_no           1.000000 -0.093480 -0.218428 -0.102250  0.041467 -0.072432
# ssc_p          -0.093480  1.000000  0.293416  0.380657  0.317892  0.430560
# hsc_p          -0.218428  0.293416  1.000000  0.221307  0.284672  0.329983
# degree_p       -0.102250  0.380657  0.221307  1.000000  0.217683  0.494093
# etest_p         0.041467  0.317892  0.284672  0.217683  1.000000  0.284143
# mba_p          -0.072432  0.430560  0.329983  0.494093  0.284143  1.000000
# salary          0.063764  0.035330  0.076819 -0.019272  0.178307  0.175013
# gender          0.079037 -0.175577 -0.023683 -0.197983  0.126781 -0.240746
# ssc_b           0.019583  0.199567 -0.132643  0.099129  0.098825  0.099025
# hsc_b           0.041571  0.141686 -0.053084  0.074791  0.043846  0.057165
# hsc_s           0.017821  0.271656 -0.247155  0.157694  0.050984  0.038855
# ...
