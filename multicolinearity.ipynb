# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
# ...

# %%
#MULTI COLINEARITY-VARIANCE INFLACTION FACTOR

#Serial no create some problem so we need to drop,it

#inplace=True imeans any changes done that it is stored in dataset.because it is not assigned nwew varible

# %%
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      5.0  85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4      8.0  82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 143  210.0  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  211.0  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
# ...

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# 4    82.00  64.00     66.00     67.0  62.14  252000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 143  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 144  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 145  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 146  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 147  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
#
#        hsc_b     hsc_s   degree_t workex specialisation  status
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def cal_vif(X):
    vif=pd.DataFrame()
    vif["variables"]=X.columns
    vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return(vif)

# %%
#vif=pd.DataFrame() - Create Table 
#vif["variables"]=X.columns-It gives name of column belongs to parameter X
#vif["VIF"]=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
  # In the above coding first for loop is executed .X.shape[1] gives column name.range(X.shape[1] gives no of column name.Then number is assigned to 
  # variable i.for eg (X.values,1) means it gives the value of 1st column then we are find VIF of corresponding column.

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        print(columnName)
        if(dataset[columnName].dtype=='O'):
            print("qual")
            qual.append(columnName)
        else:
            print("quan")
            quan.append(columnName)
    return quan

# %%
quanqual(dataset)
# Out:
# ssc_p
# quan
# hsc_p
# quan
# degree_p
# quan
# etest_p
# quan
# mba_p
# quan
# salary
# quan
# gender
# qual
# ssc_b
# qual
# hsc_b
# qual
# hsc_s
# qual
# degree_t
# qual
# workex
# qual
# specialisation
# qual
# status
# qual
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
cal_vif(dataset[['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']])
# Out:
#   variables         VIF
# 0     ssc_p   92.542386
# 1     hsc_p   64.913495
# 2  degree_p  133.057116
# 3   etest_p   35.980186
# 4     mba_p  167.558834
# 5    salary   11.166150

# %%
cal_vif(dataset[['ssc_p', 'hsc_p', 'degree_p', 'etest_p','salary']])
# Out:
#   variables        VIF
# 0     ssc_p  84.206047
# 1     hsc_p  60.308065
# 2  degree_p  88.877474
# 3   etest_p  35.719135
# 4    salary  10.541401

# %%
cal_vif(dataset[['hsc_p','etest_p']])
# Out:
#   variables        VIF
# 0     hsc_p  26.999824
# 1   etest_p  26.999824

# %%
cal_vif(dataset[[ 'mba_p','salary']])
# Out:
#   variables        VIF
# 0     mba_p  10.792565
# 1    salary  10.792565

# %%
cal_vif(dataset[[ 'etest_p','salary']])
# Out:
#   variables       VIF
# 0   etest_p  9.440124
# 1    salary  9.440124

# %%
cal_vif(dataset[[ 'ssc_p','salary']])
# Out:
#   variables       VIF
# 0     ssc_p  9.530646
# 1    salary  9.530646

# %%
cal_vif(dataset[['degree_p','salary']])
# Out:
#   variables       VIF
# 0  degree_p  9.673913
# 1    salary  9.673913

# %%
cal_vif(dataset[['hsc_p','degree_p']])
# Out:
#   variables        VIF
# 0     hsc_p  48.436149
# 1  degree_p  48.436149
